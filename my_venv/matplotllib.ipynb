# %%
#why do we need  visualization? >> for summarization of data
#matplotlib,seaborn,plotly,bokeh are the libraries that are used for visulaztion
#matplotlib>>Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings

# %%
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line,scatter,bar,histogram,piechart,box plot,violin plot
#generate random numbers in numpy
import numpy as np

x = np.random.rand(50)

# %%
x
# Out:
# array([0.87200828, 0.07407134, 0.06269452, 0.47393247, 0.20147733,
#        0.73489379, 0.85342926, 0.89399973, 0.94371792, 0.66968004,
#        0.99499169, 0.10776921, 0.25182965, 0.00773598, 0.2850212 ,
#        0.53677238, 0.27782847, 0.84042662, 0.51795577, 0.25662949,
#        0.9679008 , 0.85804601, 0.41721544, 0.60732347, 0.82785552,
#        0.63735726, 0.18661494, 0.00884761, 0.81625404, 0.3702286 ,
#        0.55979116, 0.66627889, 0.1238054 , 0.386154  , 0.34125415,
#        0.60910297, 0.83266314, 0.53579874, 0.1902141 , 0.94400465,
#        0.79281245, 0.65816104, 0.98142625, 0.8389728 , 0.45791217,
#        0.51358662, 0.86613224, 0.66789968, 0.48864176, 0.9485629 ])

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([-1.12768959, -1.27487466,  0.99806089, -0.27954088, -0.61497637,
#         0.41219419, -0.37506009, -2.2639608 , -0.18513567, -0.32380578,
#        -0.11064207,  0.47707791,  0.88489366, -0.74556371, -1.13822191,
#        -0.72443077, -0.28056357,  0.77018671,  0.66620566,  0.41780802,
#         2.43064267, -0.5842365 ,  0.14572381,  1.13187246, -0.08505288,
#        -0.57719763, -0.07752903,  0.71971313,  0.60962732, -0.04793936,
#         1.36192252,  1.21605773, -1.03182268,  0.46832054, -0.55484919,
#        -1.40653819,  1.49627683,  0.15955737,  0.73971496, -0.13549564,
#        -1.00976758, -0.15034884,  1.10370606,  1.01111861,  0.80887823,
#        -1.32151943,  2.05196627,  0.15285754,  0.34701814,  1.07503649])

# %%
df = pd.DataFrame(np.random.randn(1000),columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11 -0.292989
# 2024-07-12 -1.478282
# 2024-07-13 -0.760421
# 2024-07-14 -0.195534
# 2024-07-15 -0.193547
# ...              ...
# 2027-04-02  0.949783
# 2027-04-03 -0.067345
# 2027-04-04 -1.264451
# 2027-04-05 -0.115151
# 2027-04-06  0.856312
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,8)) #summary?>> most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.87200828, 0.07407134, 0.06269452, 0.47393247, 0.20147733,
#        0.73489379, 0.85342926, 0.89399973, 0.94371792, 0.66968004,
#        0.99499169, 0.10776921, 0.25182965, 0.00773598, 0.2850212 ,
#        0.53677238, 0.27782847, 0.84042662, 0.51795577, 0.25662949,
#        0.9679008 , 0.85804601, 0.41721544, 0.60732347, 0.82785552,
#        0.63735726, 0.18661494, 0.00884761, 0.81625404, 0.3702286 ,
#        0.55979116, 0.66627889, 0.1238054 , 0.386154  , 0.34125415,
#        0.60910297, 0.83266314, 0.53579874, 0.1902141 , 0.94400465,
#        0.79281245, 0.65816104, 0.98142625, 0.8389728 , 0.45791217,
#        0.51358662, 0.86613224, 0.66789968, 0.48864176, 0.9485629 ])

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.00646201, 0.24357183, 0.46464146, 0.58384039, 0.78862954,
#        0.33900014, 0.42644142, 0.57508183, 0.27022645, 0.21107091,
#        0.12232814, 0.89488584, 0.76310817, 0.1704281 , 0.57238263,
#        0.94409763, 0.13123275, 0.40016017, 0.53802217, 0.16728668,
#        0.4113175 , 0.95796478, 0.38865298, 0.73631998, 0.07536757,
#        0.42894022, 0.80584931, 0.21923873, 0.22882492, 0.43683608,
#        0.29690282, 0.2634418 , 0.42429734, 0.53400792, 0.78625313,
#        0.69821466, 0.34816173, 0.24109757, 0.64554182, 0.37192821,
#        0.76539583, 0.98171906, 0.68111938, 0.31511271, 0.53200895,
#        0.11295126, 0.25802491, 0.60713313, 0.17947638, 0.03362028])

# %%
#scatter plot>>The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:
plt.scatter(x,y)

# %%
#line plot
#whenever you want to see the depict the relation between two variables in the form of trend
#on the x axis the date - time column is there 
x = [1,2,3,4,5] #x is no of day
y = [5,2,7,8,1] #y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color= "red" )
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color= "red" , marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.show()

# %%
x,y
# Out:
# ([1, 2, 3, 4, 5], [5, 2, 7, 8, 1])

# %%
plt.plot(x,y, color= "red" , marker = "o", linestyle = '--')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color= "red" , marker = "o", linestyle = '--', linewidth ='4')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color= "red" , marker = "o", linestyle = '--', linewidth ='4', markersize = '15')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color= "red" , marker = "o", linestyle = '--', linewidth ='4', markersize = '15')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x-points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]


plt.plot(x,y1,color = "red", marker = "o", linestyle = "--", linewidth = 3, markersize =6, label = 'liney1 as tata motors')
plt.plot(x,y2,color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize =6, label = 'liney2 as tata power')


plt.title("multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()
plt.show()

# %%
x = np.linspace(0,10,100)

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x), '--')

# %%
plt.plot(x,np.cos(x), '--')

# %%
plt.plot(x,np.sin(x), '.-')

# %%
plt.plot(x,np.sin(x), ':')

# %%
plt.figure() #initialuzing a page to make plot
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure() #initialuzing a page to make plot
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,np.sin(x+1))

plt.show()

# %%
plt.plot(x,np.sin(x), color ='blue')

# %%
plt.plot(x, np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)

plt.show()

# %%
plt.plot(x, np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')

plt.show()

# %%
plt.plot(x, np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()

plt.show()

# %%
plt.plot(x, np.sin(x-0),color = 'blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()

plt.show()

# %%
#histogram >> continous numerical data

data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data, color = 'red', bins =30)
plt.show()

# %%
#stabbed histogram >> two histograms together
data1 = np.random.normal(0,1,5000)
data2 = np.random.normal(3,2,5000)

# %%
data1
# Out:
# array([ 0.59201099,  2.40312787,  0.68944011, ...,  1.54161228,
#        -1.09769924,  0.86153068])

# %%
data2
# Out:
# array([5.03718777, 2.22768727, 3.62541537, ..., 1.13105052, 2.64865506,
#        0.73139182])

# %%
plt.hist([data1, data2], bins = 20,color = ['r', 'b'], label = ['dist1',']dist2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatterplot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)
x
# Out:
# array([0.1880051 , 0.03429375, 0.59348213, 0.91308864, 0.38990742,
#        0.71107196, 0.37442981, 0.16790789, 0.53225503, 0.32309615,
#        0.18808285, 0.38648123, 0.45805109, 0.5638252 , 0.72719058,
#        0.88221006, 0.25760441, 0.03664024, 0.54044374, 0.44191823,
#        0.17179451, 0.12734722, 0.01993671, 0.51387286, 0.138574  ,
#        0.993608  , 0.96424629, 0.6292526 , 0.57159876, 0.57860101,
#        0.83128587, 0.94011594, 0.80674303, 0.96821591, 0.68202543,
#        0.39618579, 0.28923575, 0.52143598, 0.89582888, 0.12558075,
#        0.96081923, 0.17269275, 0.1316907 , 0.61354304, 0.56943475,
#        0.07728947, 0.10914637, 0.2095833 , 0.28478073, 0.29876435])

# %%
plt.scatter(x,y , c = 'r',marker = "X")

# %%
#bar plot >> to see distribution of categorival variables
x = ["a", "b", "c","d"]#name of students
y = [4,6,1,10] #no of days present in the class

plt.bar(x,y, color = 'r') #vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a", "b", "c","d"]#name of students
y = [4,6,1,10] #no of days present in the class

plt.barh(x,y, color = 'r') #horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
#pie char >> to understand the present distribution of data
langs = ["c","python","java"]
students = [20,100,40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.title("pie chart")
plt.show()

# %%
#focus on one segment
explode = (0.0, 0.1,0.1)
langs = ["c","python","java"]
students = [20,100,40]

plt.pie(students,labels = langs,autopct = "%1.1f%%", explode = explode , shadow = True)
plt.title("piechart")
plt.show()

# %%
#3d plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z, c = 'red')

# %%
import pandas as pd
data = pd.read_csv("Bank_churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x = data['Age'],y = data["Balance"] )

# %%
data.plot.scatter(x = 'Age', y ='Balance' )
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color = 'red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color = 'red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
#box plot >> to check the distribution of data and outliers(extreme/abnormal values)
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1e79e73c380>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1e79e29e480>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1e79e6a5f70>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1e7949e5c70>}

# %%
#area plot
#an area plot , also called a stacked areaplot, is atype of data visualization that shows how various quantitaive factors have changed over time while highlighting how they all work together to form the whole.it is particularly good for illustrating how elements of a whole change over time or along a continous dimension
#A layered representation of the data is produced in an are plot by layering many variables on top of one another.the cumulative influence of all levels provides insight into the overall trend,each layer represents a separate category or variable.
#to distinguish between categories ,the space beneath each layer is frequently coloured.

# %%
years = [2021,2018,2022,2023,2017]
category1 = [20,25,30,28,35]
category2 = [10,15,20,18,25]

category3 = [5,8,10,9,15]


plt.stackplot(years,category1,category2,category3,labels = ["category1","category2","category3"], colors = ["skyblue","lightgreen","orange"])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
